# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('hacktrain.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  ID  class  20150720_N  20150602_N  20150517_N  20150501_N  \
# 0           0   1  water    637.5950     658.668   -1882.030    -1924.36
# 1           1   2  water    634.2400     593.705   -1625.790    -1672.32
# 2           3   4  water     58.0174   -1599.160         NaN    -1052.63
# 3           4   5  water     72.5180         NaN     380.436    -1256.93
# 4           7   8  water   1136.4400         NaN         NaN     1647.83
#
#    20150415_N  20150330_N  20150314_N  ...  20140610_N  20140525_N  \
# 0     997.904   -1739.990     630.087  ...         NaN   -1043.160
# 1     914.198    -692.386     707.626  ...         NaN    -933.934
# 2         NaN   -1564.630         NaN  ...    -1025.88     368.622
# 3     515.805   -1413.180    -802.942  ...    -1813.95     155.624
# 4    1935.800         NaN    2158.980  ...     1535.00    1959.430
#
#    20140509_N  20140423_N  20140407_N  20140322_N  20140218_N  20140202_N  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# ID               0
# class            0
# 20150720_N     560
# 20150602_N    1200
# 20150517_N     800
# 20150501_N     960
# 20150415_N     480
# 20150330_N    1120
# 20150314_N     720
# 20150226_N    1360
# 20150210_N     640
# 20150125_N    1040
# 20150109_N     880
# 20141117_N    1280
# 20141101_N     400
# 20141016_N    1440
# 20140930_N     800
# 20140813_N     560
# 20140626_N    1600
# 20140610_N     480
# 20140525_N     720
# 20140509_N     880
# 20140423_N    1760
# 20140407_N     640
# 20140322_N    1120
# 20140218_N    1440
# 20140202_N     560
# 20140117_N    1200
# 20140101_N     400
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True),inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# ID            0
# class         0
# 20150720_N    0
# 20150602_N    0
# 20150517_N    0
# 20150501_N    0
# 20150415_N    0
# 20150330_N    0
# 20150314_N    0
# 20150226_N    0
# 20150210_N    0
# 20150125_N    0
# 20150109_N    0
# 20141117_N    0
# 20141101_N    0
# 20141016_N    0
# 20140930_N    0
# 20140813_N    0
# 20140626_N    0
# 20140610_N    0
# 20140525_N    0
# 20140509_N    0
# 20140423_N    0
# 20140407_N    0
# 20140322_N    0
# 20140218_N    0
# 20140202_N    0
# 20140117_N    0
# 20140101_N    0
# dtype: int64

# %%
df.drop(columns=['ID'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['class']=encoder.fit_transform(df['class'])

# %%
X = df.drop(columns=['class'])
y = df['class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=40)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'penalty':['l2'],'solver':['lgbs','newton-cg'],'max_iter':[1000],'tol':[1e-4]}

# %%
clf_reg = GridSearchCV(clf,param_grid=parameters,scoring='accuracy',cv=10)
clf_reg.fit(X_train,y_train)
# Out:
# C:\Users\soumi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\soumi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\soumi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...

# %%
print(clf_reg.best_params_)
# Out:
# {'max_iter': 1000, 'penalty': 'l2', 'solver': 'newton-cg', 'tol': 0.0001}

# %%
print(clf_reg.best_score_)
# Out:
# 0.9613333333333335

# %%
y_pred = clf_reg.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score = accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.9545

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85       230
#            1       1.00      0.99      0.99      1510
#            2       0.78      0.74      0.76        43
#            3       0.85      0.83      0.84       193
#            4       0.38      1.00      0.55         3
#            5       0.73      0.90      0.81        21
#
#     accuracy                           0.95      2000
#    macro avg       0.76      0.89      0.80      2000
# weighted avg       0.96      0.95      0.96      2000

# %%
df_test = pd.read_csv('hacktest.csv')

# %%
ID=df_test['ID']

# %%
df_test.drop(columns=['ID'],inplace=True)

# %%
df_test.head()
# Out:
#    Unnamed: 0  20150720_N  20150602_N  20150517_N  20150501_N  20150415_N  \
# 0           0     7466.42     413.162     5761.00     5625.45     489.403
# 1           1     7235.26    6037.350     1027.56     6085.14    1618.050
# 2           2     7425.08    6969.980     1177.94     7408.93     861.061
# 3           3     7119.12    1731.620     6311.93     6441.61     465.979
# 4           4     7519.55    8130.260     1482.54     7879.53    1001.210
#
#    20150330_N  20150314_N  20150226_N  20150210_N  ...  20140610_N  \
# 0     3923.84    3097.110     6766.42     2829.13  ...     801.184
# 1     6668.54    2513.990     1051.69     7268.22  ...    5533.470
# 2     7644.43     814.458     1504.29     7002.63  ...    1981.390
# 3     7128.42    1649.120     6935.22     2176.80  ...     959.344
# 4     7937.60    4122.530     1094.51     7951.44  ...    7636.070
#
#    20140525_N  20140509_N  20140423_N  20140407_N  20140322_N  20140218_N  \
# ...

# %%
X = df_test

# %%
y_req = clf_reg.predict(X)
# Out:
# C:\Users\soumi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
print(y_req)
# Out:
# [4 4 4 ... 2 2 2]

# %%
y_req=encoder.inverse_transform(y_req)

# %%
Result =pd.DataFrame({
    'ID':ID,
    'class':y_req
})

# %%
Result
# Out:
#         ID    class
# 0        1  orchard
# 1        2  orchard
# 2        3  orchard
# 3        4  orchard
# 4        5  orchard
# ...    ...      ...
# 2840  2841    grass
# 2841  2842    grass
# 2842  2843    grass
# 2843  2844    grass
# 2844  2845    grass
#
# [2845 rows x 2 columns]

# %%
Result.to_csv("ML.csv",index=False)
